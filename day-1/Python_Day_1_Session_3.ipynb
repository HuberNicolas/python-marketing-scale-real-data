# %% [markdown]
# #Python - Non-technical introduction
#
# ##Session 3: "A picture is worth a thousand words: How to create a plot (matplotlib)?"
#
# This file accompanies the video lectures and provides the code for the corresponding slides.
#
# *Note:* If you want to make changes to this document, you need to save your own copy using the "Save copy in Drive" command in the "File" menu.

# %% [markdown]
# ###Preparation
#
# **Make sure to run the follwing code before continuing.** Code will prepare everything (load data, ...).

# %%
#load the Pandas package
import pandas as pd
#Read the csv file and store it in the variable "myData". Note: this file is hostes in a GitHub repository.
myData=pd.read_csv(filepath_or_buffer="https://raw.githubusercontent.com/bachmannpatrick/Python-Class/master/data/transactions.csv", sep=",")
#load matplotlib and pyplot as plt
import matplotlib.pyplot as plt

# %% [markdown]
# ###10 - Creating basic plots

# %% [markdown]
# ####**Slide:** Create the plot (1/2)

# %%
#load matplotlib and pyplot as plt
import matplotlib.pyplot as plt
#generate the plot
plt.hist(x=myData["PurchAmount"])
#show the plot
plt.show()

# %% [markdown]
# ####**Slide:** Create the plot (2/2)

# %%
plt.scatter(x=myData["PurchAmount"], y=myData["Cost"])

# %% [markdown]
# ###11 - Format basic plots

# %% [markdown]
# ####**Slide:** The standard plot output

# %%
plt.plot(myData["PurchAmount"], myData["Cost"],"o")
plt.show()

# %% [markdown]
# ####**Slide:** Change the axis lables

# %%
plt.plot(myData["PurchAmount"], myData["Cost"],"o")
plt.xlabel("Purchase Amount")
plt.ylabel("Cost")
plt.show()

# %% [markdown]
# ####**Slide:** Add a fitting and descriptive title

# %%
plt.plot(myData["PurchAmount"], myData["Cost"],"o")
plt.xlabel("Purchase Amount")
plt.ylabel("Cost")
plt.title("Costs by Purchase Amount")
plt.show()

# %% [markdown]
# ####**Slide:** Adjust the axes limits

# %%
plt.plot(myData["PurchAmount"], myData["Cost"],"o")
plt.xlabel("Purchase Amount")
plt.ylabel("Cost")
plt.title("Costs by Purchase Amount")
plt.xlim(-100,6000)
plt.ylim(-100,3500)
plt.show()

# %% [markdown]
# ####**Slide:** Change the marker type to squares

# %%
plt.plot(myData["PurchAmount"], myData["Cost"], "s")
plt.show()

# %% [markdown]
# ####**Slide:** Choose an other color

# %%
#Variant 1
plt.plot(myData["PurchAmount"], myData["Cost"], "go")
plt.show()
#Variant 2
plt.plot(myData["PurchAmount"], myData["Cost"], "o", color="green")
plt.show()

# %% [markdown]
# ####**Slide:** Change the size of the points

# %%
plt.plot(myData["PurchAmount"], myData["Cost"],"o", markersize=10)
plt.show()

# %% [markdown]
# ####**Slide:** Change the text size

# %%
plt.plot(myData["PurchAmount"], myData["Cost"], "o")
plt.xlabel("Purchase Amount", size=20)
plt.ylabel("Cost", size=20)
plt.show()

# %% [markdown]
# ####**Slide:** Make the title italic and the axis label bold

# %%
plt.plot(myData["PurchAmount"], myData["Cost"], "o")
plt.xlabel("Purchase Amount", size=20, fontweight='bold')
plt.title("Costs by Purchase Amount", style='italic')
plt.show()

# %% [markdown]
# ####**Slide:** Remove the box

# %%
from pylab import *
axes(frameon = 0)
plt.plot(myData["PurchAmount"], myData["Cost"], "o")
plt.show()

# %% [markdown]
# ####**Slide:** Change text color

# %%
plt.plot(myData["PurchAmount"], myData["Cost"], "o")
plt.xlabel("Purchase Amount", size=20, fontweight='bold', color="green")
plt.ylabel("Cost", size=20, fontweight='bold', color="blue")
plt.title("Costs by Purchase Amount", style='italic', color="red")
plt.show()

# %% [markdown]
# ####**Slide:** Why not include everything?

# %%
plt.scatter( 	x=myData["PurchAmount"], 	y=myData["Cost"])
plt.xlabel("Purchase Amount", size=20, fontweight="bold", 	color="green")
plt.ylabel("Cost", size=20, fontweight="bold", 	color="blue")
plt.title("Costs by Purchase Amount", style="italic", color="red")
plt.xlim(0,6000)
plt.ylim(0,3500)
plt.show()

# %% [markdown]
# ####**Slide:** Less is sometimes more**

# %%
plt.scatter(x=myData["PurchAmount"], 	y=myData["Cost"])
plt.xlabel("Purchase Amount")
plt.ylabel("Cost")
plt.title("Costs by Purchase Amount")
plt.xlim(0,6000)
plt.ylim(0,3500)
plt.show()

# %% [markdown]
# ###12 - Adding further features to plots

# %% [markdown]
# ####**Slide:** Add a legend to make your plot self-explanatory

# %%
plt.scatter(x=myData["PurchAmount"], y=myData["Cost"],
label='sine')
plt.legend(loc="lower right", fontsize=12, title="Legend")
plt.show()

# %% [markdown]
# ####**Slide:** Lines can be added for extra information

# %%
plt.plot(myData["PurchAmount"], myData["Cost"], "o")

fit = np.polyfit(x=myData["PurchAmount"], y=myData["Cost"], deg=1)
plt.plot(myData["PurchAmount"], fit[0] * myData["PurchAmount"] +
fit[1],"-", color="green")
plt.show()

# %% [markdown]
# ####**Slide:** Additional graphical elements can be added in the same fashion

# %%
plt.plot(myData["PurchAmount"], myData["Cost"], "o")
fit = np.polyfit(x=myData["PurchAmount"], y=myData["Cost"], deg=1)
plt.plot(myData["PurchAmount"], fit[0] * myData["PurchAmount"] +
fit[1],"-", color="green")

plt.axhline(y=0, xmin=min(myData["PurchAmount"]),
xmax=max(myData["PurchAmount"]), linewidth=0.5, color = 'k')
plt.text(4000,3300, "max costs")
plt.plot(4500, 3100, "o", color="red", markersize=10)
plt.show()

# %% [markdown]
# ####**Slide:** You might want to plot multiple graphs in one image

# %%
plt.subplot(1,2,1)
plt.hist(myData["PurchAmount"],color="green")
plt.title("Hist PurchAmount")
plt.xlabel("Purchase Amount")
plt.ylabel("Frequency")

plt.subplot(1,2,2)
plt.plot(myData["PurchAmount"],
	myData["Cost"], "o")
plt.title("Cost on PurchAmount")
plt.xlabel("Purchase Amount")
plt.ylabel("Frequency")
plt.suptitle("Multiple graphs")
plt.show()

# %% [markdown]
# ####**Slide:** Save your plot using the command line

# %%
plt.plot(myData["PurchAmount"],myData["Cost"], "o")
plt.title("Cost on PurchAmount")
plt.savefig("Output.png")
